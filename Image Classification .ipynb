# %% [markdown]
# #Image Classification
# Name : Siti Hafsah
#
# Link Data set from kaggle
# https://www.kaggle.com/kunalgupta2616/dog-vs-cat-images-data

# %% [markdown]
# #Import Libraries

# %%
#SITI HAFSAH
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

# %%
#SITI HAFSAH
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
#SITI HAFSAH
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Define Data Path

# %%
#SITI HAFSAH
train_path = "/content/gdrive/MyDrive/Studi Independe [Digital Skola]/Homework/Week 17/HW 2/dogcat/train"
test_path  = "/content/gdrive/MyDrive/Studi Independe [Digital Skola]/Homework/Week 17/HW 2/dogcat/val"

# %% [markdown]
# #Load Dataset and define Batch

# %%
#SITI HAFSAH
# Define Batch and image size
batch_size = 32
img_height = 180
img_width = 180

# %%
#SITI HAFSAH
# Call Training dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_path, image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 272 files belonging to 2 classes.

# %%
#SITI HAFSAH
# Call Testing dataset
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_path, image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 8000 files belonging to 2 classes.

# %% [markdown]
# #Check Class names

# %%
#SITI HAFSAH
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cats', 'dogs']

# %%
#SITI HAFSAH
print(test_ds.class_names)
# Out:
# ['cats', 'dogs']

# %% [markdown]
# #Visualize Sample dataset

# %%
#SITI HAFSAH
# Visualize data before training
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
#SITI HAFSAH
# Compare batch image with batch label
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# #Cache dataset to reduce training duration

# %%
#SITI HAFSAH
# Caching dataset to fasten the training process
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# #Create CNN Model

# %%
#SITI HAFSAH
# Define Number of classes
num_classes = len(class_names)

# %%
#SITI HAFSAH
# Create Model
model = Sequential([
    # Mencegah overfit dengan mempermainkan gambar
    layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),

    # Rescale ukuran dari 0-255 ke 0-1
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

    # Convolutional Process
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),

    # Berguna untuk mencegah overfit dengan mematikan beberapa filter
    layers.Dropout(0.2),

    # Membuat kumpulan oixel menjadi satu dimensi
    layers.Flatten(),

    # Neural Network layers
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),

    # Memprediksi gambar ke sejumlah kelas (male, female)
    layers.Dense(num_classes)
])

# %%
#SITI HAFSAH
# Compile model dan menentukan pengukuran error
model.compile(optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'])

# %%
#SITI HAFSAH
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  random_flip (RandomFlip)    (None, 180, 180, 3)       0
#
#  random_rotation (RandomRota  (None, 180, 180, 3)      0
#  tion)
#
#  random_zoom (RandomZoom)    (None, 180, 180, 3)       0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 4,046,274
# Trainable params: 4,046,274
# Non-trainable params: 0
# _________________________________________________________________

# %%
#SITI HAFSAH
# Mentraining Model dan menyimpan performance model ke dalam variable history
epochs=50
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=epochs
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 655s 80s/step - loss: 0.7393 - accuracy: 0.4743 - val_loss: 0.6969 - val_accuracy: 0.5000
# Epoch 2/50
# 9/9 [==============================] - 5s 675ms/step - loss: 0.6832 - accuracy: 0.5993 - val_loss: 0.7059 - val_accuracy: 0.5000
# Epoch 3/50
# 9/9 [==============================] - 5s 648ms/step - loss: 0.6933 - accuracy: 0.5846 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 4/50
# 9/9 [==============================] - 5s 651ms/step - loss: 0.6902 - accuracy: 0.5809 - val_loss: 0.6929 - val_accuracy: 0.5000
# Epoch 5/50
# 9/9 [==============================] - 5s 652ms/step - loss: 0.6753 - accuracy: 0.5625 - val_loss: 0.7097 - val_accuracy: 0.5000
# Epoch 6/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.6895 - accuracy: 0.5956 - val_loss: 0.6959 - val_accuracy: 0.5000
# Epoch 7/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.6740 - accuracy: 0.5993 - val_loss: 0.6959 - val_accuracy: 0.5000
# Epoch 8/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.6812 - accuracy: 0.5846 - val_loss: 0.7009 - val_accuracy: 0.5000
# Epoch 9/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.6660 - accuracy: 0.5846 - val_loss: 0.7065 - val_accuracy: 0.5000
# Epoch 10/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.6741 - accuracy: 0.5919 - val_loss: 0.6901 - val_accuracy: 0.5001
# Epoch 11/50
# 9/9 [==============================] - 5s 648ms/step - loss: 0.6779 - accuracy: 0.5956 - val_loss: 0.6937 - val_accuracy: 0.5000
# Epoch 12/50
# 9/9 [==============================] - 5s 644ms/step - loss: 0.6638 - accuracy: 0.5919 - val_loss: 0.6955 - val_accuracy: 0.5016
# Epoch 13/50
# 9/9 [==============================] - 5s 649ms/step - loss: 0.6557 - accuracy: 0.6103 - val_loss: 0.6891 - val_accuracy: 0.5549
# Epoch 14/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.6512 - accuracy: 0.6176 - val_loss: 0.6943 - val_accuracy: 0.5279
# Epoch 15/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.6538 - accuracy: 0.6066 - val_loss: 0.6693 - val_accuracy: 0.5870
# Epoch 16/50
# 9/9 [==============================] - 5s 651ms/step - loss: 0.6290 - accuracy: 0.6507 - val_loss: 0.6717 - val_accuracy: 0.5901
# Epoch 17/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.6240 - accuracy: 0.6581 - val_loss: 0.7007 - val_accuracy: 0.5702
# Epoch 18/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.5819 - accuracy: 0.7279 - val_loss: 0.8098 - val_accuracy: 0.5599
# Epoch 19/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.5946 - accuracy: 0.6949 - val_loss: 0.6887 - val_accuracy: 0.5931
# Epoch 20/50
# 9/9 [==============================] - 5s 656ms/step - loss: 0.5774 - accuracy: 0.7132 - val_loss: 0.8153 - val_accuracy: 0.5689
# Epoch 21/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.5568 - accuracy: 0.6765 - val_loss: 0.8944 - val_accuracy: 0.5769
# Epoch 22/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.5545 - accuracy: 0.7059 - val_loss: 0.7433 - val_accuracy: 0.5859
# Epoch 23/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.5426 - accuracy: 0.7500 - val_loss: 0.6725 - val_accuracy: 0.6474
# Epoch 24/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.4991 - accuracy: 0.7426 - val_loss: 0.7445 - val_accuracy: 0.6324
# Epoch 25/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.5382 - accuracy: 0.7463 - val_loss: 0.6764 - val_accuracy: 0.6470
# Epoch 26/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.5627 - accuracy: 0.7132 - val_loss: 0.6663 - val_accuracy: 0.6332
# Epoch 27/50
# 9/9 [==============================] - 5s 648ms/step - loss: 0.5386 - accuracy: 0.7206 - val_loss: 0.6904 - val_accuracy: 0.6263
# Epoch 28/50
# 9/9 [==============================] - 5s 645ms/step - loss: 0.5196 - accuracy: 0.7353 - val_loss: 0.8812 - val_accuracy: 0.6129
# Epoch 29/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.5031 - accuracy: 0.7610 - val_loss: 0.7033 - val_accuracy: 0.6258
# Epoch 30/50
# 9/9 [==============================] - 5s 645ms/step - loss: 0.5766 - accuracy: 0.7132 - val_loss: 0.7151 - val_accuracy: 0.5894
# Epoch 31/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.4852 - accuracy: 0.7647 - val_loss: 0.8668 - val_accuracy: 0.6025
# Epoch 32/50
# 9/9 [==============================] - 5s 651ms/step - loss: 0.4452 - accuracy: 0.7868 - val_loss: 0.8919 - val_accuracy: 0.6352
# Epoch 33/50
# 9/9 [==============================] - 5s 645ms/step - loss: 0.4459 - accuracy: 0.8088 - val_loss: 0.7248 - val_accuracy: 0.6519
# Epoch 34/50
# 9/9 [==============================] - 5s 659ms/step - loss: 0.4582 - accuracy: 0.7463 - val_loss: 0.8459 - val_accuracy: 0.6260
# Epoch 35/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.4271 - accuracy: 0.7978 - val_loss: 1.2002 - val_accuracy: 0.6003
# Epoch 36/50
# 9/9 [==============================] - 5s 648ms/step - loss: 0.4598 - accuracy: 0.7831 - val_loss: 0.8124 - val_accuracy: 0.6311
# Epoch 37/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.4600 - accuracy: 0.7868 - val_loss: 0.8166 - val_accuracy: 0.6187
# Epoch 38/50
# 9/9 [==============================] - 5s 652ms/step - loss: 0.4460 - accuracy: 0.7794 - val_loss: 0.9787 - val_accuracy: 0.6223
# Epoch 39/50
# 9/9 [==============================] - 5s 654ms/step - loss: 0.3776 - accuracy: 0.8382 - val_loss: 1.1050 - val_accuracy: 0.6380
# Epoch 40/50
# 9/9 [==============================] - 5s 644ms/step - loss: 0.3929 - accuracy: 0.8272 - val_loss: 0.9979 - val_accuracy: 0.6211
# Epoch 41/50
# 9/9 [==============================] - 5s 645ms/step - loss: 0.3997 - accuracy: 0.8199 - val_loss: 1.0455 - val_accuracy: 0.6166
# Epoch 42/50
# 9/9 [==============================] - 5s 648ms/step - loss: 0.3693 - accuracy: 0.8309 - val_loss: 0.9738 - val_accuracy: 0.6485
# Epoch 43/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.4059 - accuracy: 0.8051 - val_loss: 0.9173 - val_accuracy: 0.6606
# Epoch 44/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.3984 - accuracy: 0.8051 - val_loss: 1.0626 - val_accuracy: 0.6165
# Epoch 45/50
# 9/9 [==============================] - 5s 646ms/step - loss: 0.4094 - accuracy: 0.7978 - val_loss: 0.8915 - val_accuracy: 0.6400
# Epoch 46/50
# 9/9 [==============================] - 5s 644ms/step - loss: 0.3671 - accuracy: 0.8419 - val_loss: 1.1042 - val_accuracy: 0.6441
# Epoch 47/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.4004 - accuracy: 0.8456 - val_loss: 0.9600 - val_accuracy: 0.6351
# Epoch 48/50
# 9/9 [==============================] - 5s 647ms/step - loss: 0.3564 - accuracy: 0.8566 - val_loss: 1.0432 - val_accuracy: 0.6254
# Epoch 49/50
# 9/9 [==============================] - 5s 644ms/step - loss: 0.3434 - accuracy: 0.8493 - val_loss: 0.9740 - val_accuracy: 0.6386
# Epoch 50/50
# 9/9 [==============================] - 5s 655ms/step - loss: 0.3734 - accuracy: 0.8272 - val_loss: 0.9999 - val_accuracy: 0.6540

# %% [markdown]
# #Visualize Performance

# %%
#SITI HAFSAH
# Accuracy and Loss Visualization

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#SITI HAFSAH
# The increase of difference trend means that the training tends to overfitting
acc_difference = abs(np.array(acc) - np.array(val_acc))
loss_difference = abs(np.array(loss) - np.array(val_loss))

plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc_difference, label='Absolute Accuracy Difference')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy Difference')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss_difference, label='Absolute Loss Difference')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss Difference')
plt.show()

# %% [markdown]
# #Predict Image

# %%
#SITI HAFSAH
# Define path of the image
image_path = "/content/gdrive/MyDrive/Studi Independe [Digital Skola]/Homework/Week 17/HW 2/dogcat/val/cats/cat.4000.jpg"

# Load Image to tensorflow
img = tf.keras.utils.load_img(
    image_path, target_size=(img_height, img_width)
)

# Transform image into array
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

# Predict model
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

# Prediction Result
print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)

# Visualize Image
img
# Out:
# This image most likely belongs to cats with a 99.06 percent confidence.
# <PIL.Image.Image image mode=RGB size=180x180 at 0x7FB5F5E45D90>
